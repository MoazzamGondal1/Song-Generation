# %%
import matplotlib.pyplot as plt

# Genres
genres = ['Hip Hop', 'Rock', 'Pop']

# Training accuracies
train_accuracies = [77, 78, 76]

# Testing accuracies
test_accuracies = [32, 35, 30]

# Set up the bar width
bar_width = 0.35

# Set up the bar positions
r1 = range(len(genres))
r2 = [x + bar_width for x in r1]

# Plotting the bar chart
plt.bar(r1, train_accuracies, width=bar_width, edgecolor='blue', color='blue', label='Training Accuracy')
plt.bar(r2, test_accuracies, width=bar_width, edgecolor='orange', color='coral', label='Testing Accuracy')

# Add labels
plt.xlabel('Genres', fontweight='bold')
plt.xticks([r + bar_width/2 for r in range(len(genres))], genres)

plt.ylabel('Accuracy (%)', fontweight='bold')
plt.title('Training and Testing Accuracy for Different Genres')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Number of models
num_models = 3

# Model names
model_names = ['2 LSTM layers, 150 neurons', '1 LSTM layer, 150 neurons', '1 LSTM layer, 100 neurons']

# Final accuracy for each model
final_accuracies = [45, 70, 80]

# Plotting the stacked bar plot
plt.figure(figsize=(8, 6))
plt.bar(model_names, final_accuracies, color=['red', 'green', 'coral'])

# Add labels and title
plt.xlabel('RNN Models', fontweight='bold')
plt.ylabel('Final Training Accuracy (%)', fontweight='bold')
plt.title('Final Training Accuracy for Different RNN Models', fontweight='bold')

# Show the plot
plt.grid(axis='y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Number of models
num_models = 4

# Model names
model_names = ['2 LSTM layers, 150 neurons', '1 LSTM layer, 150 neurons', '1 LSTM layer, 100 neurons', 'Naive Bayes']

# Final accuracy for each model
final_accuracies = [45, 70, 80, 82]

# Plotting the stacked bar plot
plt.figure(figsize=(12, 5))
plt.bar(model_names, final_accuracies, color=['skyblue', 'lightgreen', 'lightcoral', 'gold'])

# Add labels and title
plt.xlabel('Models', fontweight='bold')
plt.ylabel('Final Training Accuracy (%)', fontweight='bold')
plt.title('Final Training Accuracy for Different Models', fontweight='bold')

# Show the plot
plt.grid(axis='y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Number of models
num_models = 4

# Model names
model_names = ['2 LSTM layers, 150 neurons', '1 LSTM layer, 150 neurons', '1 LSTM layer, 100 neurons', 'Naive Bayes']

# Final training and testing accuracies for each model
final_training_accuracies = [45, 70, 80, 82]
final_testing_accuracies = [30, 33, 34, 73]

# Set the width of the bars
bar_width = 0.35

# Set up the positions for the bars
r1 = np.arange(len(model_names))
r2 = [x + bar_width for x in r1]

# Plotting the bar chart
plt.figure(figsize=(12, 5))
plt.bar(r1, final_training_accuracies, width=bar_width, color='skyblue', label='Training Accuracy')
plt.bar(r2, final_testing_accuracies, width=bar_width, color='lightcoral', label='Testing Accuracy')

# Add labels and title
plt.xlabel('Models', fontweight='bold')
plt.ylabel('Accuracy (%)', fontweight='bold')
plt.title('Final Training and Testing Accuracy for Different Models', fontweight='bold')

# Show the plot
plt.xticks([r + bar_width/2 for r in range(len(model_names))], model_names)
plt.legend()
plt.grid(axis='y')
plt.show()
